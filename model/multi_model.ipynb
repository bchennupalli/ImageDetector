# %%
import os
import pandas as pd
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, models

# ======================================================
# Device Setup: Use MPS if available (M1 Pro), CUDA if available, else CPU.
# ======================================================
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print(f"[Device Setup] Using device: {device}\n")

# ======================================================
# 1. Set Up Paths and Load CSV
# ======================================================
base_dir = '/Users/bhaskarpramodchennupalli/Documents/Image_Detector'
csv_path = os.path.join(base_dir, 'train.csv')
train_data_dir = os.path.join(base_dir, 'train_data')

print("=== Step 1: Data Check and CSV Load ===")
df = pd.read_csv(csv_path)
if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])
print(f"[Step 1] Loaded CSV file with {len(df)} records.")

# Optional: Check that every file exists in the train_data directory.
missing_files = []
for i, file_path in enumerate(df['file_name']):
    filename = os.path.basename(file_path)
    full_path = os.path.join(train_data_dir, filename)
    if not os.path.exists(full_path):
        missing_files.append(full_path)
    if i % 100 == 0:
        print(f"[Step 1] Checked {i} files...")
if missing_files:
    print(f"[Step 1] Missing {len(missing_files)} files:")
    for f in missing_files:
        print("    Missing:", f)
else:
    print("[Step 1] All files exist in the train_data directory!")
print("[Step 1] Data check complete.\n")

# ======================================================
# 2. Define the Custom Dataset Class (Top-Level)
# ======================================================
print("=== Step 2: Define Custom Dataset Class ===")
class CustomImageDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        print(f"[Dataset Init] Loading CSV file: {csv_file}")
        self.data_frame = pd.read_csv(csv_file)
        if 'Unnamed: 0' in self.data_frame.columns:
            self.data_frame = self.data_frame.drop(columns=['Unnamed: 0'])
        self.transform = transform
        print(f"[Dataset Init] Loaded {len(self.data_frame)} records from {csv_file}")

    def __len__(self):
        return len(self.data_frame)

    def __getitem__(self, idx):
        file_path = self.data_frame.iloc[idx]['file_name']
        filename = os.path.basename(file_path)
        full_path = os.path.join(train_data_dir, filename)
        image = Image.open(full_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        label = self.data_frame.iloc[idx]['label']
        return image, label

print("[Step 2] CustomImageDataset class defined.\n")

# ======================================================
# 3. Define Candidate Model Architectures (Top-Level)
# ======================================================
print("=== Step 3: Define Candidate Model Architectures ===")

# Candidate 1: SimpleCNN (original model)
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv_layer = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        # After one pooling, 224x224 becomes 112x112.
        self.fc_layer = nn.Sequential(
            nn.Linear(16 * 112 * 112, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )
    
    def forward(self, x):
        x = self.conv_layer(x)
        x = x.view(x.size(0), -1)
        x = self.fc_layer(x)
        return x

# Candidate 2: DeeperCNN with extra layers
class DeeperCNN(nn.Module):
    def __init__(self):
        super(DeeperCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),  # 32 x 224 x 224
            nn.ReLU(),
            nn.MaxPool2d(2),  # -> 32 x 112 x 112
            nn.Conv2d(32, 64, kernel_size=3, padding=1),  # -> 64 x 112 x 112
            nn.ReLU(),
            nn.MaxPool2d(2)   # -> 64 x 56 x 56
        )
        self.classifier = nn.Sequential(
            nn.Linear(64 * 56 * 56, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )
    
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# Candidate 3: Pretrained ResNet18 fine-tuned for binary classification
def create_resnet18():
    weights = models.ResNet18_Weights.DEFAULT
    model = models.resnet18(weights=weights)
    num_ftrs = model.fc.in_features
    model.fc = nn.Linear(num_ftrs, 1)
    return model

print("[Step 3] Candidate model architectures defined.")

# Create a dictionary for candidate models
candidates = {
    "SimpleCNN": SimpleCNN(),
    "DeeperCNN": DeeperCNN(),
    "ResNet18": create_resnet18()
}
print("[Step 3] Candidate models stored in dictionary.\n")

# ======================================================
# 4. Define Transformations & Create Dataset, Split, and DataLoaders (Top-Level)
# ======================================================
print("=== Step 4: Create Dataset, Split, and DataLoaders ===")
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    # Uncomment if normalization is required:
    # transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
print("[Step 4] Image transformations defined.")

print("[Step 4] Creating full dataset...")
full_dataset = CustomImageDataset(csv_file=csv_path, transform=transform)
print(f"[Step 4] Full dataset size: {len(full_dataset)}")

# Split dataset into training and validation (80/20 split)
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])
print(f"[Step 4] Training set size: {len(train_dataset)}")
print(f"[Step 4] Validation set size: {len(val_dataset)}")

batch_size = 32
print(f"[Step 4] Creating DataLoaders with batch size {batch_size} and num_workers=0 (for Jupyter)...")
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
print("[Step 4] DataLoaders created.\n")

# ======================================================
# 5. Define Training and Evaluation Functions (Top-Level)
# ======================================================
print("=== Step 5: Define Training and Evaluation Functions ===")
def train_and_evaluate(model, train_loader, val_loader, criterion, optimizer, num_epochs, device):
    model.to(device)
    best_val_acc = 0.0
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.float().unsqueeze(1).to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * images.size(0)
        avg_loss = running_loss / len(train_loader.dataset)
        
        # Evaluate on validation set
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.float().unsqueeze(1).to(device)
                outputs = model(images)
                preds = torch.round(torch.sigmoid(outputs))
                total += labels.size(0)
                correct += (preds == labels).sum().item()
        val_acc = correct / total
        print(f"[Step 5] Epoch {epoch+1}/{num_epochs} | Train Loss: {avg_loss:.4f} | Val Acc: {val_acc*100:.2f}%")
        best_val_acc = max(best_val_acc, val_acc)
    return best_val_acc

criterion = nn.BCEWithLogitsLoss()
print("[Step 5] Training and evaluation functions defined.\n")

# ======================================================
# 6. Train Candidate Models and Select the Best One
# ======================================================
print("=== Step 6: Training Candidate Models ===")
num_epochs = 5
results = {}
for name, model_candidate in candidates.items():
    print(f"\n[Step 6] Training candidate model: {name}")
    model_candidate.to(device)
    optimizer = optim.Adam(model_candidate.parameters(), lr=0.001)
    val_acc = train_and_evaluate(model_candidate, train_loader, val_loader, criterion, optimizer, num_epochs, device)
    results[name] = val_acc
    print(f"[Step 6] Candidate {name} achieved validation accuracy: {val_acc*100:.2f}%")
    
print("\n=== Step 6: Model Selection Results ===")
for name, acc in results.items():
    print(f"{name}: {acc*100:.2f}% validation accuracy")
best_model_name = max(results, key=results.get)
print(f"\n[Step 6] Best model: {best_model_name} with {results[best_model_name]*100:.2f}% validation accuracy")
print("=== Training and Model Selection Complete ===\n")
# Out:
# [Device Setup] Using device: mps
#
# === Step 1: Data Check and CSV Load ===
# [Step 1] Loaded CSV file with 79950 records.
# [Step 1] Checked 0 files...
# [Step 1] Checked 100 files...
# [Step 1] Checked 200 files...
# [Step 1] Checked 300 files...
# [Step 1] Checked 400 files...
# [Step 1] Checked 500 files...
# [Step 1] Checked 600 files...
# [Step 1] Checked 700 files...
# [Step 1] Checked 800 files...
# [Step 1] Checked 900 files...
# [Step 1] Checked 1000 files...
# [Step 1] Checked 1100 files...
# [Step 1] Checked 1200 files...
# [Step 1] Checked 1300 files...
# [Step 1] Checked 1400 files...
# [Step 1] Checked 1500 files...
# [Step 1] Checked 1600 files...
# [Step 1] Checked 1700 files...
# [Step 1] Checked 1800 files...
# [Step 1] Checked 1900 files...
# [Step 1] Checked 2000 files...
# [Step 1] Checked 2100 files...
# [Step 1] Checked 2200 files...
# [Step 1] Checked 2300 files...
# [Step 1] Checked 2400 files...
# [Step 1] Checked 2500 files...
# [Step 1] Checked 2600 files...
# [Step 1] Checked 2700 files...
# [Step 1] Checked 2800 files...
# [Step 1] Checked 2900 files...
# [Step 1] Checked 3000 files...
# [Step 1] Checked 3100 files...
# [Step 1] Checked 3200 files...
# [Step 1] Checked 3300 files...
# [Step 1] Checked 3400 files...
# [Step 1] Checked 3500 files...
# [Step 1] Checked 3600 files...
# [Step 1] Checked 3700 files...
# [Step 1] Checked 3800 files...
# [Step 1] Checked 3900 files...
# [Step 1] Checked 4000 files...
# [Step 1] Checked 4100 files...
# [Step 1] Checked 4200 files...
# [Step 1] Checked 4300 files...
# [Step 1] Checked 4400 files...
# [Step 1] Checked 4500 files...
# [Step 1] Checked 4600 files...
# [Step 1] Checked 4700 files...
# [Step 1] Checked 4800 files...
# [Step 1] Checked 4900 files...
# [Step 1] Checked 5000 files...
# [Step 1] Checked 5100 files...
# [Step 1] Checked 5200 files...
# [Step 1] Checked 5300 files...
# [Step 1] Checked 5400 files...
# [Step 1] Checked 5500 files...
# [Step 1] Checked 5600 files...
# [Step 1] Checked 5700 files...
# [Step 1] Checked 5800 files...
# [Step 1] Checked 5900 files...
# [Step 1] Checked 6000 files...
# [Step 1] Checked 6100 files...
# [Step 1] Checked 6200 files...
# [Step 1] Checked 6300 files...
# [Step 1] Checked 6400 files...
# [Step 1] Checked 6500 files...
# [Step 1] Checked 6600 files...
# [Step 1] Checked 6700 files...
# [Step 1] Checked 6800 files...
# [Step 1] Checked 6900 files...
# [Step 1] Checked 7000 files...
# [Step 1] Checked 7100 files...
# [Step 1] Checked 7200 files...
# [Step 1] Checked 7300 files...
# [Step 1] Checked 7400 files...
# [Step 1] Checked 7500 files...
# [Step 1] Checked 7600 files...
# [Step 1] Checked 7700 files...
# [Step 1] Checked 7800 files...
# [Step 1] Checked 7900 files...
# [Step 1] Checked 8000 files...
# [Step 1] Checked 8100 files...
# [Step 1] Checked 8200 files...
# [Step 1] Checked 8300 files...
# [Step 1] Checked 8400 files...
# [Step 1] Checked 8500 files...
# [Step 1] Checked 8600 files...
# [Step 1] Checked 8700 files...
# [Step 1] Checked 8800 files...
# [Step 1] Checked 8900 files...
# [Step 1] Checked 9000 files...
# [Step 1] Checked 9100 files...
# [Step 1] Checked 9200 files...
# [Step 1] Checked 9300 files...
# [Step 1] Checked 9400 files...
# [Step 1] Checked 9500 files...
# [Step 1] Checked 9600 files...
# [Step 1] Checked 9700 files...
# [Step 1] Checked 9800 files...
# [Step 1] Checked 9900 files...
# [Step 1] Checked 10000 files...
# [Step 1] Checked 10100 files...
# [Step 1] Checked 10200 files...
# [Step 1] Checked 10300 files...
# [Step 1] Checked 10400 files...
# [Step 1] Checked 10500 files...
# [Step 1] Checked 10600 files...
# [Step 1] Checked 10700 files...
# [Step 1] Checked 10800 files...
# [Step 1] Checked 10900 files...
# [Step 1] Checked 11000 files...
# [Step 1] Checked 11100 files...
# [Step 1] Checked 11200 files...
# [Step 1] Checked 11300 files...
# [Step 1] Checked 11400 files...
# [Step 1] Checked 11500 files...
# [Step 1] Checked 11600 files...
# [Step 1] Checked 11700 files...
# [Step 1] Checked 11800 files...
# [Step 1] Checked 11900 files...
# [Step 1] Checked 12000 files...
# [Step 1] Checked 12100 files...
# [Step 1] Checked 12200 files...
# [Step 1] Checked 12300 files...
# [Step 1] Checked 12400 files...
# [Step 1] Checked 12500 files...
# [Step 1] Checked 12600 files...
# [Step 1] Checked 12700 files...
# [Step 1] Checked 12800 files...
# [Step 1] Checked 12900 files...
# [Step 1] Checked 13000 files...
# [Step 1] Checked 13100 files...
# [Step 1] Checked 13200 files...
# [Step 1] Checked 13300 files...
# [Step 1] Checked 13400 files...
# [Step 1] Checked 13500 files...
# [Step 1] Checked 13600 files...
# [Step 1] Checked 13700 files...
# [Step 1] Checked 13800 files...
# [Step 1] Checked 13900 files...
# [Step 1] Checked 14000 files...
# [Step 1] Checked 14100 files...
# [Step 1] Checked 14200 files...
# [Step 1] Checked 14300 files...
# [Step 1] Checked 14400 files...
# [Step 1] Checked 14500 files...
# [Step 1] Checked 14600 files...
# [Step 1] Checked 14700 files...
# [Step 1] Checked 14800 files...
# [Step 1] Checked 14900 files...
# [Step 1] Checked 15000 files...
# [Step 1] Checked 15100 files...
# [Step 1] Checked 15200 files...
# [Step 1] Checked 15300 files...
# [Step 1] Checked 15400 files...
# [Step 1] Checked 15500 files...
# [Step 1] Checked 15600 files...
# [Step 1] Checked 15700 files...
# [Step 1] Checked 15800 files...
# [Step 1] Checked 15900 files...
# [Step 1] Checked 16000 files...
# [Step 1] Checked 16100 files...
# [Step 1] Checked 16200 files...
# [Step 1] Checked 16300 files...
# [Step 1] Checked 16400 files...
# [Step 1] Checked 16500 files...
# [Step 1] Checked 16600 files...
# [Step 1] Checked 16700 files...
# [Step 1] Checked 16800 files...
# [Step 1] Checked 16900 files...
# [Step 1] Checked 17000 files...
# [Step 1] Checked 17100 files...
# [Step 1] Checked 17200 files...
# [Step 1] Checked 17300 files...
# [Step 1] Checked 17400 files...
# [Step 1] Checked 17500 files...
# [Step 1] Checked 17600 files...
# [Step 1] Checked 17700 files...
# [Step 1] Checked 17800 files...
# [Step 1] Checked 17900 files...
# [Step 1] Checked 18000 files...
# [Step 1] Checked 18100 files...
# [Step 1] Checked 18200 files...
# [Step 1] Checked 18300 files...
# [Step 1] Checked 18400 files...
# [Step 1] Checked 18500 files...
# [Step 1] Checked 18600 files...
# [Step 1] Checked 18700 files...
# [Step 1] Checked 18800 files...
# [Step 1] Checked 18900 files...
# [Step 1] Checked 19000 files...
# [Step 1] Checked 19100 files...
# [Step 1] Checked 19200 files...
# [Step 1] Checked 19300 files...
# [Step 1] Checked 19400 files...
# [Step 1] Checked 19500 files...
# [Step 1] Checked 19600 files...
# [Step 1] Checked 19700 files...
# [Step 1] Checked 19800 files...
# [Step 1] Checked 19900 files...
# [Step 1] Checked 20000 files...
# [Step 1] Checked 20100 files...
# [Step 1] Checked 20200 files...
# [Step 1] Checked 20300 files...
# [Step 1] Checked 20400 files...
# [Step 1] Checked 20500 files...
# [Step 1] Checked 20600 files...
# [Step 1] Checked 20700 files...
# [Step 1] Checked 20800 files...
# [Step 1] Checked 20900 files...
# [Step 1] Checked 21000 files...
# [Step 1] Checked 21100 files...
# [Step 1] Checked 21200 files...
# [Step 1] Checked 21300 files...
# [Step 1] Checked 21400 files...
# [Step 1] Checked 21500 files...
# [Step 1] Checked 21600 files...
# [Step 1] Checked 21700 files...
# [Step 1] Checked 21800 files...
# [Step 1] Checked 21900 files...
# [Step 1] Checked 22000 files...
# [Step 1] Checked 22100 files...
# [Step 1] Checked 22200 files...
# [Step 1] Checked 22300 files...
# [Step 1] Checked 22400 files...
# [Step 1] Checked 22500 files...
# [Step 1] Checked 22600 files...
# [Step 1] Checked 22700 files...
# [Step 1] Checked 22800 files...
# [Step 1] Checked 22900 files...
# [Step 1] Checked 23000 files...
# [Step 1] Checked 23100 files...
# [Step 1] Checked 23200 files...
# [Step 1] Checked 23300 files...
# [Step 1] Checked 23400 files...
# [Step 1] Checked 23500 files...
# [Step 1] Checked 23600 files...
# [Step 1] Checked 23700 files...
# [Step 1] Checked 23800 files...
# [Step 1] Checked 23900 files...
# [Step 1] Checked 24000 files...
# [Step 1] Checked 24100 files...
# [Step 1] Checked 24200 files...
# [Step 1] Checked 24300 files...
# [Step 1] Checked 24400 files...
# [Step 1] Checked 24500 files...
# [Step 1] Checked 24600 files...
# [Step 1] Checked 24700 files...
# [Step 1] Checked 24800 files...
# [Step 1] Checked 24900 files...
# [Step 1] Checked 25000 files...
# [Step 1] Checked 25100 files...
# [Step 1] Checked 25200 files...
# [Step 1] Checked 25300 files...
# [Step 1] Checked 25400 files...
# [Step 1] Checked 25500 files...
# [Step 1] Checked 25600 files...
# [Step 1] Checked 25700 files...
# [Step 1] Checked 25800 files...
# [Step 1] Checked 25900 files...
# [Step 1] Checked 26000 files...
# [Step 1] Checked 26100 files...
# [Step 1] Checked 26200 files...
# [Step 1] Checked 26300 files...
# [Step 1] Checked 26400 files...
# [Step 1] Checked 26500 files...
# [Step 1] Checked 26600 files...
# [Step 1] Checked 26700 files...
# [Step 1] Checked 26800 files...
# [Step 1] Checked 26900 files...
# [Step 1] Checked 27000 files...
# [Step 1] Checked 27100 files...
# [Step 1] Checked 27200 files...
# [Step 1] Checked 27300 files...
# [Step 1] Checked 27400 files...
# [Step 1] Checked 27500 files...
# [Step 1] Checked 27600 files...
# [Step 1] Checked 27700 files...
# [Step 1] Checked 27800 files...
# [Step 1] Checked 27900 files...
# [Step 1] Checked 28000 files...
# [Step 1] Checked 28100 files...
# [Step 1] Checked 28200 files...
# [Step 1] Checked 28300 files...
# [Step 1] Checked 28400 files...
# [Step 1] Checked 28500 files...
# [Step 1] Checked 28600 files...
# [Step 1] Checked 28700 files...
# [Step 1] Checked 28800 files...
# [Step 1] Checked 28900 files...
# [Step 1] Checked 29000 files...
# [Step 1] Checked 29100 files...
# [Step 1] Checked 29200 files...
# [Step 1] Checked 29300 files...
# [Step 1] Checked 29400 files...
# [Step 1] Checked 29500 files...
# [Step 1] Checked 29600 files...
# [Step 1] Checked 29700 files...
# [Step 1] Checked 29800 files...
# [Step 1] Checked 29900 files...
# [Step 1] Checked 30000 files...
# [Step 1] Checked 30100 files...
# [Step 1] Checked 30200 files...
# [Step 1] Checked 30300 files...
# [Step 1] Checked 30400 files...
# [Step 1] Checked 30500 files...
# [Step 1] Checked 30600 files...
# [Step 1] Checked 30700 files...
# [Step 1] Checked 30800 files...
# [Step 1] Checked 30900 files...
# [Step 1] Checked 31000 files...
# [Step 1] Checked 31100 files...
# [Step 1] Checked 31200 files...
# [Step 1] Checked 31300 files...
# [Step 1] Checked 31400 files...
# [Step 1] Checked 31500 files...
# [Step 1] Checked 31600 files...
# [Step 1] Checked 31700 files...
# [Step 1] Checked 31800 files...
# [Step 1] Checked 31900 files...
# [Step 1] Checked 32000 files...
# [Step 1] Checked 32100 files...
# [Step 1] Checked 32200 files...
# [Step 1] Checked 32300 files...
# [Step 1] Checked 32400 files...
# [Step 1] Checked 32500 files...
# [Step 1] Checked 32600 files...
# [Step 1] Checked 32700 files...
# [Step 1] Checked 32800 files...
# [Step 1] Checked 32900 files...
# [Step 1] Checked 33000 files...
# [Step 1] Checked 33100 files...
# [Step 1] Checked 33200 files...
# [Step 1] Checked 33300 files...
# [Step 1] Checked 33400 files...
# [Step 1] Checked 33500 files...
# [Step 1] Checked 33600 files...
# [Step 1] Checked 33700 files...
# [Step 1] Checked 33800 files...
# [Step 1] Checked 33900 files...
# [Step 1] Checked 34000 files...
# [Step 1] Checked 34100 files...
# [Step 1] Checked 34200 files...
# [Step 1] Checked 34300 files...
# [Step 1] Checked 34400 files...
# [Step 1] Checked 34500 files...
# [Step 1] Checked 34600 files...
# [Step 1] Checked 34700 files...
# [Step 1] Checked 34800 files...
# [Step 1] Checked 34900 files...
# [Step 1] Checked 35000 files...
# [Step 1] Checked 35100 files...
# [Step 1] Checked 35200 files...
# [Step 1] Checked 35300 files...
# [Step 1] Checked 35400 files...
# [Step 1] Checked 35500 files...
# [Step 1] Checked 35600 files...
# [Step 1] Checked 35700 files...
# [Step 1] Checked 35800 files...
# [Step 1] Checked 35900 files...
# [Step 1] Checked 36000 files...
# [Step 1] Checked 36100 files...
# [Step 1] Checked 36200 files...
# [Step 1] Checked 36300 files...
# [Step 1] Checked 36400 files...
# [Step 1] Checked 36500 files...
# [Step 1] Checked 36600 files...
# [Step 1] Checked 36700 files...
# [Step 1] Checked 36800 files...
# [Step 1] Checked 36900 files...
# [Step 1] Checked 37000 files...
# [Step 1] Checked 37100 files...
# [Step 1] Checked 37200 files...
# [Step 1] Checked 37300 files...
# [Step 1] Checked 37400 files...
# [Step 1] Checked 37500 files...
# [Step 1] Checked 37600 files...
# [Step 1] Checked 37700 files...
# [Step 1] Checked 37800 files...
# [Step 1] Checked 37900 files...
# [Step 1] Checked 38000 files...
# [Step 1] Checked 38100 files...
# [Step 1] Checked 38200 files...
# [Step 1] Checked 38300 files...
# [Step 1] Checked 38400 files...
# [Step 1] Checked 38500 files...
# [Step 1] Checked 38600 files...
# [Step 1] Checked 38700 files...
# [Step 1] Checked 38800 files...
# [Step 1] Checked 38900 files...
# [Step 1] Checked 39000 files...
# [Step 1] Checked 39100 files...
# [Step 1] Checked 39200 files...
# [Step 1] Checked 39300 files...
# [Step 1] Checked 39400 files...
# [Step 1] Checked 39500 files...
# [Step 1] Checked 39600 files...
# [Step 1] Checked 39700 files...
# [Step 1] Checked 39800 files...
# [Step 1] Checked 39900 files...
# [Step 1] Checked 40000 files...
# [Step 1] Checked 40100 files...
# [Step 1] Checked 40200 files...
# [Step 1] Checked 40300 files...
# [Step 1] Checked 40400 files...
# [Step 1] Checked 40500 files...
# [Step 1] Checked 40600 files...
# [Step 1] Checked 40700 files...
# [Step 1] Checked 40800 files...
# [Step 1] Checked 40900 files...
# [Step 1] Checked 41000 files...
# [Step 1] Checked 41100 files...
# [Step 1] Checked 41200 files...
# [Step 1] Checked 41300 files...
# [Step 1] Checked 41400 files...
# [Step 1] Checked 41500 files...
# [Step 1] Checked 41600 files...
# [Step 1] Checked 41700 files...
# [Step 1] Checked 41800 files...
# [Step 1] Checked 41900 files...
# [Step 1] Checked 42000 files...
# [Step 1] Checked 42100 files...
# [Step 1] Checked 42200 files...
# [Step 1] Checked 42300 files...
# [Step 1] Checked 42400 files...
# [Step 1] Checked 42500 files...
# [Step 1] Checked 42600 files...
# [Step 1] Checked 42700 files...
# [Step 1] Checked 42800 files...
# [Step 1] Checked 42900 files...
# [Step 1] Checked 43000 files...
# [Step 1] Checked 43100 files...
# [Step 1] Checked 43200 files...
# [Step 1] Checked 43300 files...
# [Step 1] Checked 43400 files...
# [Step 1] Checked 43500 files...
# [Step 1] Checked 43600 files...
# [Step 1] Checked 43700 files...
# [Step 1] Checked 43800 files...
# [Step 1] Checked 43900 files...
# [Step 1] Checked 44000 files...
# [Step 1] Checked 44100 files...
# [Step 1] Checked 44200 files...
# [Step 1] Checked 44300 files...
# [Step 1] Checked 44400 files...
# [Step 1] Checked 44500 files...
# [Step 1] Checked 44600 files...
# [Step 1] Checked 44700 files...
# [Step 1] Checked 44800 files...
# [Step 1] Checked 44900 files...
# [Step 1] Checked 45000 files...
# [Step 1] Checked 45100 files...
# [Step 1] Checked 45200 files...
# [Step 1] Checked 45300 files...
# [Step 1] Checked 45400 files...
# [Step 1] Checked 45500 files...
# [Step 1] Checked 45600 files...
# [Step 1] Checked 45700 files...
# [Step 1] Checked 45800 files...
# [Step 1] Checked 45900 files...
# [Step 1] Checked 46000 files...
# [Step 1] Checked 46100 files...
# [Step 1] Checked 46200 files...
# [Step 1] Checked 46300 files...
# [Step 1] Checked 46400 files...
# [Step 1] Checked 46500 files...
# [Step 1] Checked 46600 files...
# [Step 1] Checked 46700 files...
# [Step 1] Checked 46800 files...
# [Step 1] Checked 46900 files...
# [Step 1] Checked 47000 files...
# [Step 1] Checked 47100 files...
# [Step 1] Checked 47200 files...
# [Step 1] Checked 47300 files...
# [Step 1] Checked 47400 files...
# [Step 1] Checked 47500 files...
# [Step 1] Checked 47600 files...
# [Step 1] Checked 47700 files...
# [Step 1] Checked 47800 files...
# [Step 1] Checked 47900 files...
# [Step 1] Checked 48000 files...
# [Step 1] Checked 48100 files...
# [Step 1] Checked 48200 files...
# [Step 1] Checked 48300 files...
# [Step 1] Checked 48400 files...
# [Step 1] Checked 48500 files...
# [Step 1] Checked 48600 files...
# [Step 1] Checked 48700 files...
# [Step 1] Checked 48800 files...
# [Step 1] Checked 48900 files...
# [Step 1] Checked 49000 files...
# [Step 1] Checked 49100 files...
# [Step 1] Checked 49200 files...
# [Step 1] Checked 49300 files...
# [Step 1] Checked 49400 files...
# [Step 1] Checked 49500 files...
# [Step 1] Checked 49600 files...
# [Step 1] Checked 49700 files...
# [Step 1] Checked 49800 files...
# [Step 1] Checked 49900 files...
# [Step 1] Checked 50000 files...
# [Step 1] Checked 50100 files...
# [Step 1] Checked 50200 files...
# [Step 1] Checked 50300 files...
# [Step 1] Checked 50400 files...
# [Step 1] Checked 50500 files...
# [Step 1] Checked 50600 files...
# [Step 1] Checked 50700 files...
# [Step 1] Checked 50800 files...
# [Step 1] Checked 50900 files...
# [Step 1] Checked 51000 files...
# [Step 1] Checked 51100 files...
# [Step 1] Checked 51200 files...
# [Step 1] Checked 51300 files...
# [Step 1] Checked 51400 files...
# [Step 1] Checked 51500 files...
# [Step 1] Checked 51600 files...
# [Step 1] Checked 51700 files...
# [Step 1] Checked 51800 files...
# [Step 1] Checked 51900 files...
# [Step 1] Checked 52000 files...
# [Step 1] Checked 52100 files...
# [Step 1] Checked 52200 files...
# [Step 1] Checked 52300 files...
# [Step 1] Checked 52400 files...
# [Step 1] Checked 52500 files...
# [Step 1] Checked 52600 files...
# [Step 1] Checked 52700 files...
# [Step 1] Checked 52800 files...
# [Step 1] Checked 52900 files...
# [Step 1] Checked 53000 files...
# [Step 1] Checked 53100 files...
# [Step 1] Checked 53200 files...
# [Step 1] Checked 53300 files...
# [Step 1] Checked 53400 files...
# [Step 1] Checked 53500 files...
# [Step 1] Checked 53600 files...
# [Step 1] Checked 53700 files...
# [Step 1] Checked 53800 files...
# [Step 1] Checked 53900 files...
# [Step 1] Checked 54000 files...
# [Step 1] Checked 54100 files...
# [Step 1] Checked 54200 files...
# [Step 1] Checked 54300 files...
# [Step 1] Checked 54400 files...
# [Step 1] Checked 54500 files...
# [Step 1] Checked 54600 files...
# [Step 1] Checked 54700 files...
# [Step 1] Checked 54800 files...
# [Step 1] Checked 54900 files...
# [Step 1] Checked 55000 files...
# [Step 1] Checked 55100 files...
# [Step 1] Checked 55200 files...
# [Step 1] Checked 55300 files...
# [Step 1] Checked 55400 files...
# [Step 1] Checked 55500 files...
# [Step 1] Checked 55600 files...
# [Step 1] Checked 55700 files...
# [Step 1] Checked 55800 files...
# [Step 1] Checked 55900 files...
# [Step 1] Checked 56000 files...
# [Step 1] Checked 56100 files...
# [Step 1] Checked 56200 files...
# [Step 1] Checked 56300 files...
# [Step 1] Checked 56400 files...
# [Step 1] Checked 56500 files...
# [Step 1] Checked 56600 files...
# [Step 1] Checked 56700 files...
# [Step 1] Checked 56800 files...
# [Step 1] Checked 56900 files...
# [Step 1] Checked 57000 files...
# [Step 1] Checked 57100 files...
# [Step 1] Checked 57200 files...
# [Step 1] Checked 57300 files...
# [Step 1] Checked 57400 files...
# [Step 1] Checked 57500 files...
# [Step 1] Checked 57600 files...
# [Step 1] Checked 57700 files...
# [Step 1] Checked 57800 files...
# [Step 1] Checked 57900 files...
# [Step 1] Checked 58000 files...
# [Step 1] Checked 58100 files...
# [Step 1] Checked 58200 files...
# [Step 1] Checked 58300 files...
# [Step 1] Checked 58400 files...
# [Step 1] Checked 58500 files...
# [Step 1] Checked 58600 files...
# [Step 1] Checked 58700 files...
# [Step 1] Checked 58800 files...
# [Step 1] Checked 58900 files...
# [Step 1] Checked 59000 files...
# [Step 1] Checked 59100 files...
# [Step 1] Checked 59200 files...
# [Step 1] Checked 59300 files...
# [Step 1] Checked 59400 files...
# [Step 1] Checked 59500 files...
# [Step 1] Checked 59600 files...
# [Step 1] Checked 59700 files...
# [Step 1] Checked 59800 files...
# [Step 1] Checked 59900 files...
# [Step 1] Checked 60000 files...
# [Step 1] Checked 60100 files...
# [Step 1] Checked 60200 files...
# [Step 1] Checked 60300 files...
# [Step 1] Checked 60400 files...
# [Step 1] Checked 60500 files...
# [Step 1] Checked 60600 files...
# [Step 1] Checked 60700 files...
# [Step 1] Checked 60800 files...
# [Step 1] Checked 60900 files...
# [Step 1] Checked 61000 files...
# [Step 1] Checked 61100 files...
# [Step 1] Checked 61200 files...
# [Step 1] Checked 61300 files...
# [Step 1] Checked 61400 files...
# [Step 1] Checked 61500 files...
# [Step 1] Checked 61600 files...
# [Step 1] Checked 61700 files...
# [Step 1] Checked 61800 files...
# [Step 1] Checked 61900 files...
# [Step 1] Checked 62000 files...
# [Step 1] Checked 62100 files...
# [Step 1] Checked 62200 files...
# [Step 1] Checked 62300 files...
# [Step 1] Checked 62400 files...
# [Step 1] Checked 62500 files...
# [Step 1] Checked 62600 files...
# [Step 1] Checked 62700 files...
# [Step 1] Checked 62800 files...
# [Step 1] Checked 62900 files...
# [Step 1] Checked 63000 files...
# [Step 1] Checked 63100 files...
# [Step 1] Checked 63200 files...
# [Step 1] Checked 63300 files...
# [Step 1] Checked 63400 files...
# [Step 1] Checked 63500 files...
# [Step 1] Checked 63600 files...
# [Step 1] Checked 63700 files...
# [Step 1] Checked 63800 files...
# [Step 1] Checked 63900 files...
# [Step 1] Checked 64000 files...
# [Step 1] Checked 64100 files...
# [Step 1] Checked 64200 files...
# [Step 1] Checked 64300 files...
# [Step 1] Checked 64400 files...
# [Step 1] Checked 64500 files...
# [Step 1] Checked 64600 files...
# [Step 1] Checked 64700 files...
# [Step 1] Checked 64800 files...
# [Step 1] Checked 64900 files...
# [Step 1] Checked 65000 files...
# [Step 1] Checked 65100 files...
# [Step 1] Checked 65200 files...
# [Step 1] Checked 65300 files...
# [Step 1] Checked 65400 files...
# [Step 1] Checked 65500 files...
# [Step 1] Checked 65600 files...
# [Step 1] Checked 65700 files...
# [Step 1] Checked 65800 files...
# [Step 1] Checked 65900 files...
# [Step 1] Checked 66000 files...
# [Step 1] Checked 66100 files...
# [Step 1] Checked 66200 files...
# [Step 1] Checked 66300 files...
# [Step 1] Checked 66400 files...
# [Step 1] Checked 66500 files...
# [Step 1] Checked 66600 files...
# [Step 1] Checked 66700 files...
# [Step 1] Checked 66800 files...
# [Step 1] Checked 66900 files...
# [Step 1] Checked 67000 files...
# [Step 1] Checked 67100 files...
# [Step 1] Checked 67200 files...
# [Step 1] Checked 67300 files...
# [Step 1] Checked 67400 files...
# [Step 1] Checked 67500 files...
# [Step 1] Checked 67600 files...
# [Step 1] Checked 67700 files...
# [Step 1] Checked 67800 files...
# [Step 1] Checked 67900 files...
# [Step 1] Checked 68000 files...
# [Step 1] Checked 68100 files...
# [Step 1] Checked 68200 files...
# [Step 1] Checked 68300 files...
# [Step 1] Checked 68400 files...
# [Step 1] Checked 68500 files...
# [Step 1] Checked 68600 files...
# [Step 1] Checked 68700 files...
# [Step 1] Checked 68800 files...
# [Step 1] Checked 68900 files...
# [Step 1] Checked 69000 files...
# [Step 1] Checked 69100 files...
# [Step 1] Checked 69200 files...
# [Step 1] Checked 69300 files...
# [Step 1] Checked 69400 files...
# [Step 1] Checked 69500 files...
# [Step 1] Checked 69600 files...
# [Step 1] Checked 69700 files...
# [Step 1] Checked 69800 files...
# [Step 1] Checked 69900 files...
# [Step 1] Checked 70000 files...
# [Step 1] Checked 70100 files...
# [Step 1] Checked 70200 files...
# [Step 1] Checked 70300 files...
# [Step 1] Checked 70400 files...
# [Step 1] Checked 70500 files...
# [Step 1] Checked 70600 files...
# [Step 1] Checked 70700 files...
# [Step 1] Checked 70800 files...
# [Step 1] Checked 70900 files...
# [Step 1] Checked 71000 files...
# [Step 1] Checked 71100 files...
# [Step 1] Checked 71200 files...
# [Step 1] Checked 71300 files...
# [Step 1] Checked 71400 files...
# [Step 1] Checked 71500 files...
# [Step 1] Checked 71600 files...
# [Step 1] Checked 71700 files...
# [Step 1] Checked 71800 files...
# [Step 1] Checked 71900 files...
# [Step 1] Checked 72000 files...
# [Step 1] Checked 72100 files...
# [Step 1] Checked 72200 files...
# [Step 1] Checked 72300 files...
# [Step 1] Checked 72400 files...
# [Step 1] Checked 72500 files...
# [Step 1] Checked 72600 files...
# [Step 1] Checked 72700 files...
# [Step 1] Checked 72800 files...
# [Step 1] Checked 72900 files...
# [Step 1] Checked 73000 files...
# [Step 1] Checked 73100 files...
# [Step 1] Checked 73200 files...
# [Step 1] Checked 73300 files...
# [Step 1] Checked 73400 files...
# [Step 1] Checked 73500 files...
# [Step 1] Checked 73600 files...
# [Step 1] Checked 73700 files...
# [Step 1] Checked 73800 files...
# [Step 1] Checked 73900 files...
# [Step 1] Checked 74000 files...
# [Step 1] Checked 74100 files...
# [Step 1] Checked 74200 files...
# [Step 1] Checked 74300 files...
# [Step 1] Checked 74400 files...
# [Step 1] Checked 74500 files...
# [Step 1] Checked 74600 files...
# [Step 1] Checked 74700 files...
# [Step 1] Checked 74800 files...
# [Step 1] Checked 74900 files...
# [Step 1] Checked 75000 files...
# [Step 1] Checked 75100 files...
# [Step 1] Checked 75200 files...
# [Step 1] Checked 75300 files...
# [Step 1] Checked 75400 files...
# [Step 1] Checked 75500 files...
# [Step 1] Checked 75600 files...
# [Step 1] Checked 75700 files...
# [Step 1] Checked 75800 files...
# [Step 1] Checked 75900 files...
# [Step 1] Checked 76000 files...
# [Step 1] Checked 76100 files...
# [Step 1] Checked 76200 files...
# [Step 1] Checked 76300 files...
# [Step 1] Checked 76400 files...
# [Step 1] Checked 76500 files...
# [Step 1] Checked 76600 files...
# [Step 1] Checked 76700 files...
# [Step 1] Checked 76800 files...
# [Step 1] Checked 76900 files...
# [Step 1] Checked 77000 files...
# [Step 1] Checked 77100 files...
# [Step 1] Checked 77200 files...
# [Step 1] Checked 77300 files...
# [Step 1] Checked 77400 files...
# [Step 1] Checked 77500 files...
# [Step 1] Checked 77600 files...
# [Step 1] Checked 77700 files...
# [Step 1] Checked 77800 files...
# [Step 1] Checked 77900 files...
# [Step 1] Checked 78000 files...
# [Step 1] Checked 78100 files...
# [Step 1] Checked 78200 files...
# [Step 1] Checked 78300 files...
# [Step 1] Checked 78400 files...
# [Step 1] Checked 78500 files...
# [Step 1] Checked 78600 files...
# [Step 1] Checked 78700 files...
# [Step 1] Checked 78800 files...
# [Step 1] Checked 78900 files...
# [Step 1] Checked 79000 files...
# [Step 1] Checked 79100 files...
# [Step 1] Checked 79200 files...
# [Step 1] Checked 79300 files...
# [Step 1] Checked 79400 files...
# [Step 1] Checked 79500 files...
# [Step 1] Checked 79600 files...
# [Step 1] Checked 79700 files...
# [Step 1] Checked 79800 files...
# [Step 1] Checked 79900 files...
# [Step 1] All files exist in the train_data directory!
# [Step 1] Data check complete.
#
# === Step 2: Define Custom Dataset Class ===
# [Step 2] CustomImageDataset class defined.
#
# === Step 3: Define Candidate Model Architectures ===
# [Step 3] Candidate model architectures defined.
# [Step 3] Candidate models stored in dictionary.
#
# === Step 4: Create Dataset, Split, and DataLoaders ===
# [Step 4] Image transformations defined.
# [Step 4] Creating full dataset...
# [Dataset Init] Loading CSV file: /Users/bhaskarpramodchennupalli/Documents/Image_Detector/train.csv
# [Dataset Init] Loaded 79950 records from /Users/bhaskarpramodchennupalli/Documents/Image_Detector/train.csv
# [Step 4] Full dataset size: 79950
# [Step 4] Training set size: 63960
# [Step 4] Validation set size: 15990
# [Step 4] Creating DataLoaders with batch size 32 and num_workers=0 (for Jupyter)...
# [Step 4] DataLoaders created.
#
# === Step 5: Define Training and Evaluation Functions ===
# [Step 5] Training and evaluation functions defined.
#
# === Step 6: Training Candidate Models ===
#
# [Step 6] Training candidate model: SimpleCNN
# [Step 5] Epoch 1/5 | Train Loss: 0.2961 | Val Acc: 90.79%
# [Step 5] Epoch 2/5 | Train Loss: 0.1930 | Val Acc: 92.37%
# [Step 5] Epoch 3/5 | Train Loss: 0.1357 | Val Acc: 93.52%
# [Step 5] Epoch 4/5 | Train Loss: 0.0870 | Val Acc: 93.61%
# [Step 5] Epoch 5/5 | Train Loss: 0.0604 | Val Acc: 93.03%
# [Step 6] Candidate SimpleCNN achieved validation accuracy: 93.61%
#
# [Step 6] Training candidate model: DeeperCNN
# [Step 5] Epoch 1/5 | Train Loss: 0.2562 | Val Acc: 91.31%
# [Step 5] Epoch 2/5 | Train Loss: 0.1607 | Val Acc: 94.48%
# [Step 5] Epoch 3/5 | Train Loss: 0.0965 | Val Acc: 94.67%
# [Step 5] Epoch 4/5 | Train Loss: 0.0587 | Val Acc: 94.96%
# [Step 5] Epoch 5/5 | Train Loss: 0.0335 | Val Acc: 95.97%
# [Step 6] Candidate DeeperCNN achieved validation accuracy: 95.97%
#
# [Step 6] Training candidate model: ResNet18
# [Step 5] Epoch 1/5 | Train Loss: 0.1365 | Val Acc: 84.07%
# [Step 5] Epoch 2/5 | Train Loss: 0.0567 | Val Acc: 97.69%
# [Step 5] Epoch 3/5 | Train Loss: 0.0410 | Val Acc: 97.99%
# [Step 5] Epoch 4/5 | Train Loss: 0.0343 | Val Acc: 98.90%
# [Step 5] Epoch 5/5 | Train Loss: 0.0307 | Val Acc: 99.34%
# [Step 6] Candidate ResNet18 achieved validation accuracy: 99.34%
#
# === Step 6: Model Selection Results ===
# SimpleCNN: 93.61% validation accuracy
# DeeperCNN: 95.97% validation accuracy
# ResNet18: 99.34% validation accuracy
#
# [Step 6] Best model: ResNet18 with 99.34% validation accuracy
# === Training and Model Selection Complete ===

# %%
best_model = candidates["ResNet18"]
model_save_path = os.path.join(base_dir, 'best_model.pth')
torch.save(best_model.state_dict(), model_save_path)
print(f"Best model saved to {model_save_path}")
# Out:
# Best model saved to /Users/bhaskarpramodchennupalli/Documents/Image_Detector/best_model.pth
